# %% [markdown]
# # Data Inspecting #
#
# After downloading the data and setting up a Python environment with the required packages, the next step is inspecting the data contents in order to determine which weather variables are available to access.
#
# The processing used to `inspect(this section)` and `preprocess(next section)` `.grb` is the same as in `.grb2`. But there may be some difference in `lookup key` between them. For not confusing you, we will only use the `.grb2` as an example.
#
# Assume that we want 5 weather data:
# - `latitude`
# - `longitude`
# - `temperature`
# - `wind_speed`
# - `wind_direction`

# %% [markdown]
# # Import Libraries

# %%
import Nio
import xarray as xr

# %% [markdown]
# # Open Dataset
# Open the `GRIB2 data(.grb2)` with `xarray` using `PyNIO` as its engine

# %%
ds = xr.open_dataset("data/gfsanl_4_20171107_0000_000.grb2", engine="pynio")

# %% [markdown]
# # Overview of each variables
# For each of the variables, print the `lookup key`, `human-readable name`, and `units of measurement`

# %%
for v in ds:
    print("{}, {}, {}".format(v, ds[v].attrs["long_name"], ds[v].attrs["units"]))
# Out:
# TMP_P0_L1_GLL0, Temperature, K
# TMP_P0_L6_GLL0, Temperature, K
# TMP_P0_L7_GLL0, Temperature, K
# TMP_P0_L100_GLL0, Temperature, K
# TMP_P0_L102_GLL0, Temperature, K
# TMP_P0_L103_GLL0, Temperature, K
# TMP_P0_L104_GLL0, Temperature, K
# TMP_P0_2L108_GLL0, Temperature, K
# TMP_P0_L109_GLL0, Temperature, K
# POT_P0_L104_GLL0, Potential temperature, K
# DPT_P0_L103_GLL0, Dew point temperature, K
# APTMP_P0_L103_GLL0, Apparent temperature, K
# SPFH_P0_L103_GLL0, Specific humidity, kg kg-1
# SPFH_P0_2L108_GLL0, Specific humidity, kg kg-1
# RH_P0_L4_GLL0, Relative humidity, %
# RH_P0_L100_GLL0, Relative humidity, %
# RH_P0_L103_GLL0, Relative humidity, %
# RH_P0_2L104_GLL0, Relative humidity, %
# RH_P0_L104_GLL0, Relative humidity, %
# RH_P0_2L108_GLL0, Relative humidity, %
# RH_P0_L200_GLL0, Relative humidity, %
# RH_P0_L204_GLL0, Relative humidity, %
# PWAT_P0_L200_GLL0, Precipitable water, kg m-2
# SNOD_P0_L1_GLL0, Snow depth, m
# WEASD_P0_L1_GLL0, Water equivalent of accumulated snow depth, kg m-2
# CLWMR_P0_L100_GLL0, Cloud mixing ratio, kg kg-1
# CPOFP_P0_L1_GLL0, Percent frozen precipitation, %
# UGRD_P0_L6_GLL0, U-component of wind, m s-1
# UGRD_P0_L7_GLL0, U-component of wind, m s-1
# UGRD_P0_L100_GLL0, U-component of wind, m s-1
# UGRD_P0_L102_GLL0, U-component of wind, m s-1
# UGRD_P0_L103_GLL0, U-component of wind, m s-1
# UGRD_P0_L104_GLL0, U-component of wind, m s-1
# UGRD_P0_2L108_GLL0, U-component of wind, m s-1
# UGRD_P0_L109_GLL0, U-component of wind, m s-1
# UGRD_P0_L220_GLL0, U-component of wind, m s-1
# VGRD_P0_L6_GLL0, V-component of wind, m s-1
# VGRD_P0_L7_GLL0, V-component of wind, m s-1
# VGRD_P0_L100_GLL0, V-component of wind, m s-1
# VGRD_P0_L102_GLL0, V-component of wind, m s-1
# VGRD_P0_L103_GLL0, V-component of wind, m s-1
# VGRD_P0_L104_GLL0, V-component of wind, m s-1
# VGRD_P0_2L108_GLL0, V-component of wind, m s-1
# VGRD_P0_L109_GLL0, V-component of wind, m s-1
# VGRD_P0_L220_GLL0, V-component of wind, m s-1
# VVEL_P0_L100_GLL0, Vertical velocity (pressure), Pa s-1
# VVEL_P0_L104_GLL0, Vertical velocity (pressure), Pa s-1
# ABSV_P0_L100_GLL0, Absolute vorticity, s-1
# GUST_P0_L1_GLL0, Wind speed (gust), m s-1
# VWSH_P0_L7_GLL0, Vertical speed shear, s-1
# VWSH_P0_L109_GLL0, Vertical speed shear, s-1
# USTM_P0_2L103_GLL0, U-component storm motion, m s-1
# VSTM_P0_2L103_GLL0, V-component storm motion, m s-1
# VRATE_P0_L220_GLL0, Ventilation rate, m2 s-1
# PRES_P0_L1_GLL0, Pressure, Pa
# PRES_P0_L6_GLL0, Pressure, Pa
# PRES_P0_L7_GLL0, Pressure, Pa
# PRES_P0_L103_GLL0, Pressure, Pa
# PRES_P0_L109_GLL0, Pressure, Pa
# PRMSL_P0_L101_GLL0, Pressure reduced to MSL, Pa
# ICAHT_P0_L6_GLL0, ICAO standard atmosphere reference height, m
# ICAHT_P0_L7_GLL0, ICAO standard atmosphere reference height, m
# HGT_P0_L1_GLL0, Geopotential height, gpm
# HGT_P0_L4_GLL0, Geopotential height, gpm
# HGT_P0_L6_GLL0, Geopotential height, gpm
# HGT_P0_L7_GLL0, Geopotential height, gpm
# HGT_P0_L100_GLL0, Geopotential height, gpm
# HGT_P0_L109_GLL0, Geopotential height, gpm
# HGT_P0_L204_GLL0, Geopotential height, gpm
# MSLET_P0_L101_GLL0, MSLP (ETA model reduction), Pa
# 5WAVH_P0_L100_GLL0, 5-wave geopotential height, gpm
# HPBL_P0_L1_GLL0, Planetary boundary layer height, m
# PLPL_P0_2L108_GLL0, Pressure of level from which parcel was lifted, Pa
# CWAT_P0_L200_GLL0, Cloud water, kg m-2
# SUNSD_P0_L1_GLL0, Sunshine duration, s
# CAPE_P0_L1_GLL0, Convective available potential energy, J kg-1
# CAPE_P0_2L108_GLL0, Convective available potential energy, J kg-1
# CIN_P0_L1_GLL0, Convective inhibition, J kg-1
# CIN_P0_2L108_GLL0, Convective inhibition, J kg-1
# HLCY_P0_2L103_GLL0, Storm relative helicity, m2 s-2
# LFTX_P0_L1_GLL0, Surface lifted index, K
# 4LFTX_P0_L1_GLL0, Best (4 layer) lifted index, K
# TOZNE_P0_L200_GLL0, Total ozone, Dobson
# O3MR_P0_L100_GLL0, Ozone mixing ratio, kg kg-1
# VIS_P0_L1_GLL0, Visibility, m
# LAND_P0_L1_GLL0, Land cover (1=land, 0=sea), Proportion
# TSOIL_P0_2L106_GLL0, Soil temperature, K
# SOILW_P0_2L106_GLL0, Volumetric soil moisture content, Fraction
# WILT_P0_L1_GLL0, Wilting point, Fraction
# LANDN_P0_L1_GLL0, Land-sea coverage (nearest neighbor) [land=1,sea=0], -
# FLDCP_P0_L1_GLL0, Field capacity, fraction
# HINDEX_P0_L1_GLL0, Haines index, Numeric
# ICEC_P0_L1_GLL0, Ice cover, Proportion
# lv_DBLL11_l1, Depth below land surface, m
# lv_DBLL11_l0, Depth below land surface, m
# lv_SPDL9_l1, Level at specified pressure difference from ground to level, Pa
# lv_SPDL9_l0, Level at specified pressure difference from ground to level, Pa
# lv_SIGL5_l1, Sigma level (sigma value), none
# lv_SIGL5_l0, Sigma level (sigma value), none

# %% [markdown]
# # Details of desirable variables
# As you can see that there are many `lookup key` that has the same `human-readable name` e.g. `Temperature` , `U-component of wind` , `V-component of wind`
#
# So, for more details, you can print the `full metadata` of each desirable variable
#
# In this tutorial, we will use the `Temperature` as an example

# %%
temperature = ["TMP_P0_L1_GLL0", "TMP_P0_L6_GLL0", "TMP_P0_L7_GLL0", "TMP_P0_L100_GLL0", "TMP_P0_L102_GLL0", "TMP_P0_L103_GLL0", "TMP_P0_L104_GLL0", "TMP_P0_2L108_GLL0", "TMP_P0_L109_GLL0"]
for key in temperature:
    print(ds[key])
    print("-------------------------------------------------------------------------------------------")
# Out:
# <xarray.DataArray 'TMP_P0_L1_GLL0' (lat_0: 361, lon_0: 720)>
# [259920 values with dtype=float32]
# Coordinates:
#   * lat_0    (lat_0) float32 90.0 89.5 89.0 88.5 ... -88.5 -89.0 -89.5 -90.0
#   * lon_0    (lon_0) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
# Attributes:
#     center:                                         US National Weather Servi...
#     production_status:                              Operational products
#     long_name:                                      Temperature
#     units:                                          K
#     grid_type:                                      Latitude/longitude
#     parameter_discipline_and_category:              Meteorological products, ...
#     parameter_template_discipline_category_number:  [0 0 0 0]
#     level_type:                                     Ground or water surface
#     level:                                          [0.]
#     forecast_time:                                  [0]
#     forecast_time_units:                            hours
#     initial_time:                                   11/07/2017 (00:00)
# -------------------------------------------------------------------------------------------
# <xarray.DataArray 'TMP_P0_L6_GLL0' (lat_0: 361, lon_0: 720)>
# [259920 values with dtype=float32]
# Coordinates:
#   * lat_0    (lat_0) float32 90.0 89.5 89.0 88.5 ... -88.5 -89.0 -89.5 -90.0
#   * lon_0    (lon_0) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
# Attributes:
#     center:                                         US National Weather Servi...
#     production_status:                              Operational products
#     long_name:                                      Temperature
#     units:                                          K
#     grid_type:                                      Latitude/longitude
#     parameter_discipline_and_category:              Meteorological products, ...
#     parameter_template_discipline_category_number:  [0 0 0 0]
#     level_type:                                     Maximum wind level
#     level:                                          [0.]
#     forecast_time:                                  [0]
#     forecast_time_units:                            hours
#     initial_time:                                   11/07/2017 (00:00)
# -------------------------------------------------------------------------------------------
# <xarray.DataArray 'TMP_P0_L7_GLL0' (lat_0: 361, lon_0: 720)>
# [259920 values with dtype=float32]
# Coordinates:
#   * lat_0    (lat_0) float32 90.0 89.5 89.0 88.5 ... -88.5 -89.0 -89.5 -90.0
#   * lon_0    (lon_0) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
# Attributes:
#     center:                                         US National Weather Servi...
#     production_status:                              Operational products
#     long_name:                                      Temperature
#     units:                                          K
#     grid_type:                                      Latitude/longitude
#     parameter_discipline_and_category:              Meteorological products, ...
#     parameter_template_discipline_category_number:  [0 0 0 0]
#     level_type:                                     Tropopause
#     level:                                          [0.]
#     forecast_time:                                  [0]
#     forecast_time_units:                            hours
#     initial_time:                                   11/07/2017 (00:00)
# -------------------------------------------------------------------------------------------
# <xarray.DataArray 'TMP_P0_L100_GLL0' (lv_ISBL0: 31, lat_0: 361, lon_0: 720)>
# [8057520 values with dtype=float32]
# Coordinates:
#   * lv_ISBL0  (lv_ISBL0) float32 100.0 200.0 300.0 ... 95000.0 97500.0 100000.0
#   * lat_0     (lat_0) float32 90.0 89.5 89.0 88.5 ... -88.5 -89.0 -89.5 -90.0
#   * lon_0     (lon_0) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
# Attributes:
#     center:                                         US National Weather Servi...
#     production_status:                              Operational products
#     long_name:                                      Temperature
#     units:                                          K
#     grid_type:                                      Latitude/longitude
#     parameter_discipline_and_category:              Meteorological products, ...
#     parameter_template_discipline_category_number:  [0 0 0 0]
#     level_type:                                     Isobaric surface (Pa)
#     forecast_time:                                  [0]
#     forecast_time_units:                            hours
#     initial_time:                                   11/07/2017 (00:00)
# -------------------------------------------------------------------------------------------
# <xarray.DataArray 'TMP_P0_L102_GLL0' (lv_AMSL1: 3, lat_0: 361, lon_0: 720)>
# [779760 values with dtype=float32]
# Coordinates:
#   * lv_AMSL1  (lv_AMSL1) float32 1829.0 2743.0 3658.0
#   * lat_0     (lat_0) float32 90.0 89.5 89.0 88.5 ... -88.5 -89.0 -89.5 -90.0
#   * lon_0     (lon_0) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
# Attributes:
#     center:                                         US National Weather Servi...
#     production_status:                              Operational products
#     long_name:                                      Temperature
#     units:                                          K
#     grid_type:                                      Latitude/longitude
#     parameter_discipline_and_category:              Meteorological products, ...
#     parameter_template_discipline_category_number:  [0 0 0 0]
#     level_type:                                     Specific altitude above m...
#     forecast_time:                                  [0]
#     forecast_time_units:                            hours
#     initial_time:                                   11/07/2017 (00:00)
# -------------------------------------------------------------------------------------------
# <xarray.DataArray 'TMP_P0_L103_GLL0' (lv_HTGL2: 3, lat_0: 361, lon_0: 720)>
# [779760 values with dtype=float32]
# Coordinates:
#   * lv_HTGL2  (lv_HTGL2) float32 2.0 80.0 100.0
#   * lat_0     (lat_0) float32 90.0 89.5 89.0 88.5 ... -88.5 -89.0 -89.5 -90.0
#   * lon_0     (lon_0) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
# Attributes:
#     center:                                         US National Weather Servi...
#     production_status:                              Operational products
#     long_name:                                      Temperature
#     units:                                          K
#     grid_type:                                      Latitude/longitude
#     parameter_discipline_and_category:              Meteorological products, ...
#     parameter_template_discipline_category_number:  [0 0 0 0]
#     level_type:                                     Specified height level ab...
#     forecast_time:                                  [0]
#     forecast_time_units:                            hours
#     initial_time:                                   11/07/2017 (00:00)
# -------------------------------------------------------------------------------------------
# <xarray.DataArray 'TMP_P0_L104_GLL0' (lat_0: 361, lon_0: 720)>
# [259920 values with dtype=float32]
# Coordinates:
#   * lat_0    (lat_0) float32 90.0 89.5 89.0 88.5 ... -88.5 -89.0 -89.5 -90.0
#   * lon_0    (lon_0) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
# Attributes:
#     center:                                         US National Weather Servi...
#     production_status:                              Operational products
#     long_name:                                      Temperature
#     units:                                          K
#     grid_type:                                      Latitude/longitude
#     parameter_discipline_and_category:              Meteorological products, ...
#     parameter_template_discipline_category_number:  [0 0 0 0]
#     level_type:                                     Sigma level (sigma value)
#     level:                                          [0.995]
#     forecast_time:                                  [0]
#     forecast_time_units:                            hours
#     initial_time:                                   11/07/2017 (00:00)
# -------------------------------------------------------------------------------------------
# <xarray.DataArray 'TMP_P0_2L108_GLL0' (lat_0: 361, lon_0: 720)>
# [259920 values with dtype=float32]
# Coordinates:
#   * lat_0    (lat_0) float32 90.0 89.5 89.0 88.5 ... -88.5 -89.0 -89.5 -90.0
#   * lon_0    (lon_0) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
# Attributes:
#     center:                                         US National Weather Servi...
#     production_status:                              Operational products
#     long_name:                                      Temperature
#     units:                                          K
#     grid_type:                                      Latitude/longitude
#     parameter_discipline_and_category:              Meteorological products, ...
#     parameter_template_discipline_category_number:  [0 0 0 0]
#     level_type:                                     Level at specified pressu...
#     level:                                          [3000.    0.]
#     forecast_time:                                  [0]
#     forecast_time_units:                            hours
#     initial_time:                                   11/07/2017 (00:00)
# -------------------------------------------------------------------------------------------
# <xarray.DataArray 'TMP_P0_L109_GLL0' (lv_PVL3: 2, lat_0: 361, lon_0: 720)>
# [519840 values with dtype=float32]
# Coordinates:
#   * lv_PVL3  (lv_PVL3) float32 -2e-06 2e-06
#   * lat_0    (lat_0) float32 90.0 89.5 89.0 88.5 ... -88.5 -89.0 -89.5 -90.0
#   * lon_0    (lon_0) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
# Attributes:
#     center:                                         US National Weather Servi...
#     production_status:                              Operational products
#     long_name:                                      Temperature
#     units:                                          K
#     grid_type:                                      Latitude/longitude
#     parameter_discipline_and_category:              Meteorological products, ...
#     parameter_template_discipline_category_number:  [0 0 0 0]
#     level_type:                                     Potential vorticity (K m2...
#     forecast_time:                                  [0]
#     forecast_time_units:                            hours
#     initial_time:                                   11/07/2017 (00:00)
# -------------------------------------------------------------------------------------------

# %% [markdown]
# The `Coordinates` are the index of each data
#
# You can print only the different attribute in each desirable variable, which is `level_type` to be easier to compare!

# %%
for key in temperature:
    print(key)
    print(ds[key].level_type)
    print("--------------------------------------")
# Out:
# TMP_P0_L1_GLL0
# Ground or water surface
# --------------------------------------
# TMP_P0_L6_GLL0
# Maximum wind level
# --------------------------------------
# TMP_P0_L7_GLL0
# Tropopause
# --------------------------------------
# TMP_P0_L100_GLL0
# Isobaric surface (Pa)
# --------------------------------------
# TMP_P0_L102_GLL0
# Specific altitude above mean sea level (m)
# --------------------------------------
# TMP_P0_L103_GLL0
# Specified height level above ground (m)
# --------------------------------------
# TMP_P0_L104_GLL0
# Sigma level (sigma value)
# --------------------------------------
# TMP_P0_2L108_GLL0
# Level at specified pressure difference from ground to level (Pa)
# --------------------------------------
# TMP_P0_L109_GLL0
# Potential vorticity (K m2 kg-1 s-1)
# --------------------------------------

# %% [markdown]
# At this point, it requires some technical knowledge about the meaning of each `Temperature` data
#
# In my case, I choose the `Isobaric surface (Pa)` which is a surface in the atmosphere where the pressure is equal everywhere along that surface.

# %%
ds.get("TMP_P0_L100_GLL0")
# Out:
# <xarray.DataArray 'TMP_P0_L100_GLL0' (lv_ISBL0: 31, lat_0: 361, lon_0: 720)>
# [8057520 values with dtype=float32]
# Coordinates:
#   * lv_ISBL0  (lv_ISBL0) float32 100.0 200.0 300.0 ... 95000.0 97500.0 100000.0
#   * lat_0     (lat_0) float32 90.0 89.5 89.0 88.5 ... -88.5 -89.0 -89.5 -90.0
#   * lon_0     (lon_0) float32 0.0 0.5 1.0 1.5 2.0 ... 358.0 358.5 359.0 359.5
# Attributes:
#     center:                                         US National Weather Servi...
#     production_status:                              Operational products
#     long_name:                                      Temperature
#     units:                                          K
#     grid_type:                                      Latitude/longitude
#     parameter_discipline_and_category:              Meteorological products, ...
#     parameter_template_discipline_category_number:  [0 0 0 0]
#     level_type:                                     Isobaric surface (Pa)
#     forecast_time:                                  [0]
#     forecast_time_units:                            hours
#     initial_time:                                   11/07/2017 (00:00)

# %% [markdown]
# But I need the temperature at the specific pressure which is `85000.0 Pa`
#
# So we will get all pressure that in `TMP_P0_L100_GLL0` to determine whether we can get the data we want from this lookup key.
#
# To do that, we will convert this dataset into a `pandas.DataFrame.` to be easier to process

# %%
df = ds.get("TMP_P0_L100_GLL0").to_dataframe()
df.index.get_level_values("lv_ISBL0").drop_duplicates()
# Out:
# Float64Index([   100.0,    200.0,    300.0,    500.0,    700.0,   1000.0,
#                 2000.0,   3000.0,   5000.0,   7000.0,  10000.0,  15000.0,
#                20000.0,  25000.0,  30000.0,  35000.0,  40000.0,  45000.0,
#                50000.0,  55000.0,  60000.0,  65000.0,  70000.0,  75000.0,
#                80000.0,  85000.0,  90000.0,  92500.0,  95000.0,  97500.0,
#               100000.0],
#              dtype='float64', name='lv_ISBL0')

# %% [markdown]
# At this point, you can understand all lookup key in the dataset and properly choose the one that suit your task.
#
# In my case, I selected these lookup key.
# - `TMP_P0_L1_GLL0`: Temperature(K) at ground or water surface
# - `UGRD_P0_L100_GLL0`: U-component of wind(m/s) at isobaric surface (Pa)
# - `VGRD_P0_L100_GLL0`: V-component of wind(m/s) at isobaric surface (Pa)

# %%
ds.get(["TMP_P0_L1_GLL0", "UGRD_P0_L100_GLL0", "VGRD_P0_L100_GLL0"]).to_dataframe()
# Out:
#                       TMP_P0_L1_GLL0  UGRD_P0_L100_GLL0  VGRD_P0_L100_GLL0
# lat_0 lon_0 lv_ISBL0
#  90.0 0.0   100.0         247.178085         -38.843361           4.000019
#             200.0         247.178085         -35.828548           1.100024
#             300.0         247.178085         -36.096478           0.199982
#             500.0         247.178085         -34.036407          -0.800006
#             700.0         247.178085         -31.010010          -0.700012
# ...                              ...                ...                ...
# -90.0 359.5 90000.0       243.478073           1.780039          -6.711587
#             92500.0       243.478073           1.779717          -6.711902
#             95000.0       243.478073           1.776223          -6.710415
#             97500.0       243.478073           1.772436          -6.710183
#             100000.0      243.478073           1.778059          -6.710752
#
# [8057520 rows x 3 columns]

# %% [markdown]
# Fortunately, `latitude`, `longitude` and `temperature` are directly given in this dataset.
#
# But to get the `wind_speed` and `wind_direction`, it requires some technical process to process `U-component` and `V-component`.
#
# The detail of these process are described in the next section, **Data Processing**
